# %%
from flask import Flask, render_template, redirect, url_for
from flask_pymongo import PyMongo
import scraping

# %%
app = Flask(__name__)

# %%
# Use flask_pymongo to set up mongo connection
app.config["MONGO_URI"] = "mongodb://localhost:27017/mars_app"
mongo = PyMongo(app)

#creating route to find HTML page 

@app.route("/")
def index():
   mars = mongo.db.mars.find_one()
   return render_template("index.html", mars=mars)

#scraping route

@app.route("/scrape")
def scrape():
   mars = mongo.db.mars
   mars_data = scraping.scrape_all()
   mars.update_one({}, {"$set":mars_data}, upsert=True)
   return redirect('/', code=302)

# %%
if __name__ == "__main__":
   app.run()
# Out:
#  * Serving Flask app '__main__' (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
# [2022-01-31 23:23:18,689] ERROR in app: Exception on / [GET]
# Traceback (most recent call last):
#   File "C:\Users\prave\anaconda3\lib\site-packages\flask\app.py", line 2073, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\prave\anaconda3\lib\site-packages\flask\app.py", line 1518, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\prave\anaconda3\lib\site-packages\flask\app.py", line 1516, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\prave\anaconda3\lib\site-packages\flask\app.py", line 1502, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**req.view_args)
#   File "C:\Users\prave\AppData\Local\Temp/ipykernel_27128/3971609375.py", line 10, in index
#     return render_template("index.html", mars=mars)
#   File "C:\Users\prave\anaconda3\lib\site-packages\flask\templating.py", line 148, in render_template
#     ctx.app.jinja_env.get_or_select_template(template_name_or_list),
#   File "C:\Users\prave\anaconda3\lib\site-packages\jinja2\environment.py", line 1068, in get_or_select_template
#     return self.get_template(template_name_or_list, parent, globals)
#   File "C:\Users\prave\anaconda3\lib\site-packages\jinja2\environment.py", line 997, in get_template
#     return self._load_template(name, globals)
#   File "C:\Users\prave\anaconda3\lib\site-packages\jinja2\environment.py", line 958, in _load_template
#     template = self.loader.load(self, name, self.make_globals(globals))
#   File "C:\Users\prave\anaconda3\lib\site-packages\jinja2\loaders.py", line 125, in load
#     source, filename, uptodate = self.get_source(environment, name)
#   File "C:\Users\prave\anaconda3\lib\site-packages\flask\templating.py", line 59, in get_source
#     return self._get_source_fast(environment, template)
#   File "C:\Users\prave\anaconda3\lib\site-packages\flask\templating.py", line 95, in _get_source_fast
#     raise TemplateNotFound(template)
# jinja2.exceptions.TemplateNotFound: index.html
# 127.0.0.1 - - [31/Jan/2022 23:23:18] "GET / HTTP/1.1" 500 -
# [2022-02-01 20:46:20,173] ERROR in app: Exception on / [GET]
# Traceback (most recent call last):
#   File "C:\Users\prave\anaconda3\lib\site-packages\flask\app.py", line 2073, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\prave\anaconda3\lib\site-packages\flask\app.py", line 1518, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\prave\anaconda3\lib\site-packages\flask\app.py", line 1516, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\prave\anaconda3\lib\site-packages\flask\app.py", line 1502, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**req.view_args)
#   File "C:\Users\prave\AppData\Local\Temp/ipykernel_27128/3971609375.py", line 10, in index
#     return render_template("index.html", mars=mars)
#   File "C:\Users\prave\anaconda3\lib\site-packages\flask\templating.py", line 148, in render_template
#     ctx.app.jinja_env.get_or_select_template(template_name_or_list),
#   File "C:\Users\prave\anaconda3\lib\site-packages\jinja2\environment.py", line 1068, in get_or_select_template
#     return self.get_template(template_name_or_list, parent, globals)
#   File "C:\Users\prave\anaconda3\lib\site-packages\jinja2\environment.py", line 997, in get_template
#     return self._load_template(name, globals)
#   File "C:\Users\prave\anaconda3\lib\site-packages\jinja2\environment.py", line 958, in _load_template
#     template = self.loader.load(self, name, self.make_globals(globals))
#   File "C:\Users\prave\anaconda3\lib\site-packages\jinja2\loaders.py", line 125, in load
#     source, filename, uptodate = self.get_source(environment, name)
#   File "C:\Users\prave\anaconda3\lib\site-packages\flask\templating.py", line 59, in get_source
#     return self._get_source_fast(environment, template)
#   File "C:\Users\prave\anaconda3\lib\site-packages\flask\templating.py", line 95, in _get_source_fast
#     raise TemplateNotFound(template)
# jinja2.exceptions.TemplateNotFound: index.html
# 127.0.0.1 - - [01/Feb/2022 20:46:20] "GET / HTTP/1.1" 500 -
# 127.0.0.1 - - [01/Feb/2022 21:42:49] "GET /%20(Press%20CTRL+C%20to%20quit) HTTP/1.1" 404 -
# [2022-02-01 21:43:09,354] ERROR in app: Exception on / [GET]
# Traceback (most recent call last):
#   File "C:\Users\prave\anaconda3\lib\site-packages\flask\app.py", line 2073, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\prave\anaconda3\lib\site-packages\flask\app.py", line 1518, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\prave\anaconda3\lib\site-packages\flask\app.py", line 1516, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\prave\anaconda3\lib\site-packages\flask\app.py", line 1502, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**req.view_args)
#   File "C:\Users\prave\AppData\Local\Temp/ipykernel_27128/3971609375.py", line 10, in index
#     return render_template("index.html", mars=mars)
#   File "C:\Users\prave\anaconda3\lib\site-packages\flask\templating.py", line 148, in render_template
#     ctx.app.jinja_env.get_or_select_template(template_name_or_list),
#   File "C:\Users\prave\anaconda3\lib\site-packages\jinja2\environment.py", line 1068, in get_or_select_template
#     return self.get_template(template_name_or_list, parent, globals)
#   File "C:\Users\prave\anaconda3\lib\site-packages\jinja2\environment.py", line 997, in get_template
#     return self._load_template(name, globals)
#   File "C:\Users\prave\anaconda3\lib\site-packages\jinja2\environment.py", line 958, in _load_template
#     template = self.loader.load(self, name, self.make_globals(globals))
#   File "C:\Users\prave\anaconda3\lib\site-packages\jinja2\loaders.py", line 125, in load
#     source, filename, uptodate = self.get_source(environment, name)
#   File "C:\Users\prave\anaconda3\lib\site-packages\flask\templating.py", line 59, in get_source
#     return self._get_source_fast(environment, template)
#   File "C:\Users\prave\anaconda3\lib\site-packages\flask\templating.py", line 95, in _get_source_fast
#     raise TemplateNotFound(template)
# jinja2.exceptions.TemplateNotFound: index.html
# 127.0.0.1 - - [01/Feb/2022 21:43:09] "GET / HTTP/1.1" 500 -
# [2022-02-01 21:43:12,008] ERROR in app: Exception on / [GET]
# Traceback (most recent call last):
#   File "C:\Users\prave\anaconda3\lib\site-packages\flask\app.py", line 2073, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\prave\anaconda3\lib\site-packages\flask\app.py", line 1518, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\prave\anaconda3\lib\site-packages\flask\app.py", line 1516, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\prave\anaconda3\lib\site-packages\flask\app.py", line 1502, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**req.view_args)
#   File "C:\Users\prave\AppData\Local\Temp/ipykernel_27128/3971609375.py", line 10, in index
#     return render_template("index.html", mars=mars)
#   File "C:\Users\prave\anaconda3\lib\site-packages\flask\templating.py", line 148, in render_template
#     ctx.app.jinja_env.get_or_select_template(template_name_or_list),
#   File "C:\Users\prave\anaconda3\lib\site-packages\jinja2\environment.py", line 1068, in get_or_select_template
#     return self.get_template(template_name_or_list, parent, globals)
#   File "C:\Users\prave\anaconda3\lib\site-packages\jinja2\environment.py", line 997, in get_template
#     return self._load_template(name, globals)
#   File "C:\Users\prave\anaconda3\lib\site-packages\jinja2\environment.py", line 958, in _load_template
#     template = self.loader.load(self, name, self.make_globals(globals))
#   File "C:\Users\prave\anaconda3\lib\site-packages\jinja2\loaders.py", line 125, in load
#     source, filename, uptodate = self.get_source(environment, name)
#   File "C:\Users\prave\anaconda3\lib\site-packages\flask\templating.py", line 59, in get_source
#     return self._get_source_fast(environment, template)
#   File "C:\Users\prave\anaconda3\lib\site-packages\flask\templating.py", line 95, in _get_source_fast
#     raise TemplateNotFound(template)
# jinja2.exceptions.TemplateNotFound: index.html
# 127.0.0.1 - - [01/Feb/2022 21:43:12] "GET / HTTP/1.1" 500 -
# [2022-02-01 21:43:31,860] ERROR in app: Exception on / [GET]
# Traceback (most recent call last):
#   File "C:\Users\prave\anaconda3\lib\site-packages\flask\app.py", line 2073, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\prave\anaconda3\lib\site-packages\flask\app.py", line 1518, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\prave\anaconda3\lib\site-packages\flask\app.py", line 1516, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\prave\anaconda3\lib\site-packages\flask\app.py", line 1502, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**req.view_args)
#   File "C:\Users\prave\AppData\Local\Temp/ipykernel_27128/3971609375.py", line 10, in index
#     return render_template("index.html", mars=mars)
#   File "C:\Users\prave\anaconda3\lib\site-packages\flask\templating.py", line 148, in render_template
#     ctx.app.jinja_env.get_or_select_template(template_name_or_list),
#   File "C:\Users\prave\anaconda3\lib\site-packages\jinja2\environment.py", line 1068, in get_or_select_template
#     return self.get_template(template_name_or_list, parent, globals)
#   File "C:\Users\prave\anaconda3\lib\site-packages\jinja2\environment.py", line 997, in get_template
#     return self._load_template(name, globals)
#   File "C:\Users\prave\anaconda3\lib\site-packages\jinja2\environment.py", line 958, in _load_template
#     template = self.loader.load(self, name, self.make_globals(globals))
#   File "C:\Users\prave\anaconda3\lib\site-packages\jinja2\loaders.py", line 125, in load
#     source, filename, uptodate = self.get_source(environment, name)
#   File "C:\Users\prave\anaconda3\lib\site-packages\flask\templating.py", line 59, in get_source
#     return self._get_source_fast(environment, template)
#   File "C:\Users\prave\anaconda3\lib\site-packages\flask\templating.py", line 95, in _get_source_fast
#     raise TemplateNotFound(template)
# jinja2.exceptions.TemplateNotFound: index.html
# 127.0.0.1 - - [01/Feb/2022 21:43:31] "GET / HTTP/1.1" 500 -
# [2022-02-01 21:48:30,681] ERROR in app: Exception on / [GET]
# Traceback (most recent call last):
#   File "C:\Users\prave\anaconda3\lib\site-packages\flask\app.py", line 2073, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\prave\anaconda3\lib\site-packages\flask\app.py", line 1518, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\prave\anaconda3\lib\site-packages\flask\app.py", line 1516, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\prave\anaconda3\lib\site-packages\flask\app.py", line 1502, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**req.view_args)
#   File "C:\Users\prave\AppData\Local\Temp/ipykernel_27128/3971609375.py", line 10, in index
#     return render_template("index.html", mars=mars)
#   File "C:\Users\prave\anaconda3\lib\site-packages\flask\templating.py", line 148, in render_template
#     ctx.app.jinja_env.get_or_select_template(template_name_or_list),
#   File "C:\Users\prave\anaconda3\lib\site-packages\jinja2\environment.py", line 1068, in get_or_select_template
#     return self.get_template(template_name_or_list, parent, globals)
#   File "C:\Users\prave\anaconda3\lib\site-packages\jinja2\environment.py", line 997, in get_template
#     return self._load_template(name, globals)
#   File "C:\Users\prave\anaconda3\lib\site-packages\jinja2\environment.py", line 958, in _load_template
#     template = self.loader.load(self, name, self.make_globals(globals))
#   File "C:\Users\prave\anaconda3\lib\site-packages\jinja2\loaders.py", line 125, in load
#     source, filename, uptodate = self.get_source(environment, name)
#   File "C:\Users\prave\anaconda3\lib\site-packages\flask\templating.py", line 59, in get_source
#     return self._get_source_fast(environment, template)
#   File "C:\Users\prave\anaconda3\lib\site-packages\flask\templating.py", line 95, in _get_source_fast
#     raise TemplateNotFound(template)
# jinja2.exceptions.TemplateNotFound: index.html
# 127.0.0.1 - - [01/Feb/2022 21:48:30] "GET / HTTP/1.1" 500 -
# [2022-02-01 21:48:34,247] ERROR in app: Exception on / [GET]
# Traceback (most recent call last):
#   File "C:\Users\prave\anaconda3\lib\site-packages\flask\app.py", line 2073, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\prave\anaconda3\lib\site-packages\flask\app.py", line 1518, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\prave\anaconda3\lib\site-packages\flask\app.py", line 1516, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\prave\anaconda3\lib\site-packages\flask\app.py", line 1502, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**req.view_args)
#   File "C:\Users\prave\AppData\Local\Temp/ipykernel_27128/3971609375.py", line 10, in index
#     return render_template("index.html", mars=mars)
#   File "C:\Users\prave\anaconda3\lib\site-packages\flask\templating.py", line 148, in render_template
#     ctx.app.jinja_env.get_or_select_template(template_name_or_list),
#   File "C:\Users\prave\anaconda3\lib\site-packages\jinja2\environment.py", line 1068, in get_or_select_template
#     return self.get_template(template_name_or_list, parent, globals)
#   File "C:\Users\prave\anaconda3\lib\site-packages\jinja2\environment.py", line 997, in get_template
#     return self._load_template(name, globals)
#   File "C:\Users\prave\anaconda3\lib\site-packages\jinja2\environment.py", line 958, in _load_template
#     template = self.loader.load(self, name, self.make_globals(globals))
#   File "C:\Users\prave\anaconda3\lib\site-packages\jinja2\loaders.py", line 125, in load
#     source, filename, uptodate = self.get_source(environment, name)
#   File "C:\Users\prave\anaconda3\lib\site-packages\flask\templating.py", line 59, in get_source
#     return self._get_source_fast(environment, template)
#   File "C:\Users\prave\anaconda3\lib\site-packages\flask\templating.py", line 95, in _get_source_fast
#     raise TemplateNotFound(template)
# jinja2.exceptions.TemplateNotFound: index.html
# 127.0.0.1 - - [01/Feb/2022 21:48:34] "GET / HTTP/1.1" 500 -
# [2022-02-01 21:48:46,639] ERROR in app: Exception on / [GET]
# Traceback (most recent call last):
#   File "C:\Users\prave\anaconda3\lib\site-packages\flask\app.py", line 2073, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\prave\anaconda3\lib\site-packages\flask\app.py", line 1518, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\prave\anaconda3\lib\site-packages\flask\app.py", line 1516, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\prave\anaconda3\lib\site-packages\flask\app.py", line 1502, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**req.view_args)
#   File "C:\Users\prave\AppData\Local\Temp/ipykernel_27128/3971609375.py", line 10, in index
#     return render_template("index.html", mars=mars)
#   File "C:\Users\prave\anaconda3\lib\site-packages\flask\templating.py", line 148, in render_template
#     ctx.app.jinja_env.get_or_select_template(template_name_or_list),
#   File "C:\Users\prave\anaconda3\lib\site-packages\jinja2\environment.py", line 1068, in get_or_select_template
#     return self.get_template(template_name_or_list, parent, globals)
#   File "C:\Users\prave\anaconda3\lib\site-packages\jinja2\environment.py", line 997, in get_template
#     return self._load_template(name, globals)
#   File "C:\Users\prave\anaconda3\lib\site-packages\jinja2\environment.py", line 958, in _load_template
#     template = self.loader.load(self, name, self.make_globals(globals))
#   File "C:\Users\prave\anaconda3\lib\site-packages\jinja2\loaders.py", line 125, in load
#     source, filename, uptodate = self.get_source(environment, name)
#   File "C:\Users\prave\anaconda3\lib\site-packages\flask\templating.py", line 59, in get_source
#     return self._get_source_fast(environment, template)
#   File "C:\Users\prave\anaconda3\lib\site-packages\flask\templating.py", line 95, in _get_source_fast
#     raise TemplateNotFound(template)
# jinja2.exceptions.TemplateNotFound: index.html
# 127.0.0.1 - - [01/Feb/2022 21:48:46] "GET / HTTP/1.1" 500 -
# [2022-02-01 21:50:54,552] ERROR in app: Exception on / [GET]
# Traceback (most recent call last):
#   File "C:\Users\prave\anaconda3\lib\site-packages\flask\app.py", line 2073, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\prave\anaconda3\lib\site-packages\flask\app.py", line 1518, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\prave\anaconda3\lib\site-packages\flask\app.py", line 1516, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\prave\anaconda3\lib\site-packages\flask\app.py", line 1502, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**req.view_args)
#   File "C:\Users\prave\AppData\Local\Temp/ipykernel_27128/3971609375.py", line 10, in index
#     return render_template("index.html", mars=mars)
#   File "C:\Users\prave\anaconda3\lib\site-packages\flask\templating.py", line 148, in render_template
#     ctx.app.jinja_env.get_or_select_template(template_name_or_list),
#   File "C:\Users\prave\anaconda3\lib\site-packages\jinja2\environment.py", line 1068, in get_or_select_template
#     return self.get_template(template_name_or_list, parent, globals)
#   File "C:\Users\prave\anaconda3\lib\site-packages\jinja2\environment.py", line 997, in get_template
#     return self._load_template(name, globals)
#   File "C:\Users\prave\anaconda3\lib\site-packages\jinja2\environment.py", line 958, in _load_template
#     template = self.loader.load(self, name, self.make_globals(globals))
#   File "C:\Users\prave\anaconda3\lib\site-packages\jinja2\loaders.py", line 125, in load
#     source, filename, uptodate = self.get_source(environment, name)
#   File "C:\Users\prave\anaconda3\lib\site-packages\flask\templating.py", line 59, in get_source
#     return self._get_source_fast(environment, template)
#   File "C:\Users\prave\anaconda3\lib\site-packages\flask\templating.py", line 95, in _get_source_fast
#     raise TemplateNotFound(template)
# jinja2.exceptions.TemplateNotFound: index.html
# 127.0.0.1 - - [01/Feb/2022 21:50:54] "GET / HTTP/1.1" 500 -
# [2022-02-01 21:51:15,162] ERROR in app: Exception on / [GET]
# Traceback (most recent call last):
#   File "C:\Users\prave\anaconda3\lib\site-packages\flask\app.py", line 2073, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\prave\anaconda3\lib\site-packages\flask\app.py", line 1518, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\prave\anaconda3\lib\site-packages\flask\app.py", line 1516, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\prave\anaconda3\lib\site-packages\flask\app.py", line 1502, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**req.view_args)
#   File "C:\Users\prave\AppData\Local\Temp/ipykernel_27128/3971609375.py", line 10, in index
#     return render_template("index.html", mars=mars)
#   File "C:\Users\prave\anaconda3\lib\site-packages\flask\templating.py", line 148, in render_template
#     ctx.app.jinja_env.get_or_select_template(template_name_or_list),
#   File "C:\Users\prave\anaconda3\lib\site-packages\jinja2\environment.py", line 1068, in get_or_select_template
#     return self.get_template(template_name_or_list, parent, globals)
#   File "C:\Users\prave\anaconda3\lib\site-packages\jinja2\environment.py", line 997, in get_template
#     return self._load_template(name, globals)
#   File "C:\Users\prave\anaconda3\lib\site-packages\jinja2\environment.py", line 958, in _load_template
#     template = self.loader.load(self, name, self.make_globals(globals))
#   File "C:\Users\prave\anaconda3\lib\site-packages\jinja2\loaders.py", line 125, in load
#     source, filename, uptodate = self.get_source(environment, name)
#   File "C:\Users\prave\anaconda3\lib\site-packages\flask\templating.py", line 59, in get_source
#     return self._get_source_fast(environment, template)
#   File "C:\Users\prave\anaconda3\lib\site-packages\flask\templating.py", line 95, in _get_source_fast
#     raise TemplateNotFound(template)
# jinja2.exceptions.TemplateNotFound: index.html
# 127.0.0.1 - - [01/Feb/2022 21:51:15] "GET / HTTP/1.1" 500 -
# [2022-02-01 21:54:14,608] ERROR in app: Exception on / [GET]
# Traceback (most recent call last):
#   File "C:\Users\prave\anaconda3\lib\site-packages\flask\app.py", line 2073, in wsgi_app
#     response = self.full_dispatch_request()
#   File "C:\Users\prave\anaconda3\lib\site-packages\flask\app.py", line 1518, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "C:\Users\prave\anaconda3\lib\site-packages\flask\app.py", line 1516, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "C:\Users\prave\anaconda3\lib\site-packages\flask\app.py", line 1502, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**req.view_args)
#   File "C:\Users\prave\AppData\Local\Temp/ipykernel_27128/3971609375.py", line 10, in index
#     return render_template("index.html", mars=mars)
#   File "C:\Users\prave\anaconda3\lib\site-packages\flask\templating.py", line 148, in render_template
#     ctx.app.jinja_env.get_or_select_template(template_name_or_list),
#   File "C:\Users\prave\anaconda3\lib\site-packages\jinja2\environment.py", line 1068, in get_or_select_template
#     return self.get_template(template_name_or_list, parent, globals)
#   File "C:\Users\prave\anaconda3\lib\site-packages\jinja2\environment.py", line 997, in get_template
#     return self._load_template(name, globals)
#   File "C:\Users\prave\anaconda3\lib\site-packages\jinja2\environment.py", line 958, in _load_template
#     template = self.loader.load(self, name, self.make_globals(globals))
#   File "C:\Users\prave\anaconda3\lib\site-packages\jinja2\loaders.py", line 125, in load
#     source, filename, uptodate = self.get_source(environment, name)
#   File "C:\Users\prave\anaconda3\lib\site-packages\flask\templating.py", line 59, in get_source
#     return self._get_source_fast(environment, template)
#   File "C:\Users\prave\anaconda3\lib\site-packages\flask\templating.py", line 95, in _get_source_fast
#     raise TemplateNotFound(template)
# jinja2.exceptions.TemplateNotFound: index.html
# 127.0.0.1 - - [01/Feb/2022 21:54:14] "GET / HTTP/1.1" 500 -
